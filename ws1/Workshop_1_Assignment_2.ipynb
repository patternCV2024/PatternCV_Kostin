# %%
import os
import tensorflow as tf
from tensorflow import keras

# Завантажити дані

# Отримати поточний робочий каталог
current_dir = os.getcwd()

# Додати data/mnist.npz до попереднього шляху, щоб отримати повний шлях
data_path = os.path.join(current_dir, "data/mnist.npz")

# Відмінити тестовий набір
(x_train, y_train), _ = tf.keras.datasets.mnist.load_data()

# Нормалізувати значень пікселів
x_train = x_train / 255.0

data_shape = x_train.shape

print(f"Є {data_shape[0]} прикладів із формою ({data_shape[1]}, {data_shape[2]})")

# GRADED CLASS: myCallback

# Запам'ятати успадкування від правильного класу
class myCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        if logs.get('accuracy') > 0.99:
            print("\nДосягнуто 99% точності, тому навчання скасовано!")
            self.model.stop_training = True


# GRADED FUNCTION: train_mnist
def train_mnist(x_train, y_train):

    # Створити екземпляр класу зворотного виклику
    callbacks = myCallback()

    # Визначити модель
    model = tf.keras.models.Sequential([
        tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
        tf.keras.layers.MaxPooling2D((2, 2)),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dense(10, activation='softmax')
    ])


    # Скомпілювати модель
    model.compile(optimizer='adam',
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    # Налаштувати модель на 10 епох, додавши зворотні виклики
    # і зберегти історію навчання
    history = model.fit(x_train, y_train, epochs=10, callbacks=[callbacks])

    return history

hist = train_mnist(x_train, y_train)
# Out:
# Є 60000 прикладів із формою (28, 28)
# Epoch 1/10
# 2024-04-20 17:15:03.901431: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 188160000 exceeds 10% of free system memory.
# 1875/1875 [==============================] - 52s 28ms/step - loss: 0.1437 - accuracy: 0.9574
# Epoch 2/10
# 1875/1875 [==============================] - 54s 29ms/step - loss: 0.0501 - accuracy: 0.9844
# Epoch 3/10
# 1875/1875 [==============================] - 53s 28ms/step - loss: 0.0312 - accuracy: 0.9898
# Epoch 4/10
# 1873/1875 [============================>.] - ETA: 0s - loss: 0.0206 - accuracy: 0.9936
# Досягнуто 99% точності, тому навчання скасовано!
# 1875/1875 [==============================] - 52s 28ms/step - loss: 0.0206 - accuracy: 0.9936

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=3d38360a-0652-4516-87d7-e1ead631829e' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
